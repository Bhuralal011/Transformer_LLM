# %%
# !pip install transformer >=4.46.1
# Out:
# ERROR: Could not find a version that satisfies the requirement transformer (from versions: none)
# ERROR: No matching distribution found for transformer

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# %%
#tokenizing text
from transformers import AutoTokenizer

# %%
sentence = "hello world"

# %%
tokenizer = AutoTokenizer.from_pretrained("bert-base-cased")
# Out:
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]

# %%
token_id = tokenizer(sentence)

# %%
token_id
# Out:
# {'input_ids': [101, 19082, 1362, 102], 'token_type_ids': [0, 0, 0, 0], 'attention_mask': [1, 1, 1, 1]}

# %%
token_id = tokenizer(sentence).input_ids

# %%
token_id
# Out:
# [101, 19082, 1362, 102]

# %%
for id in token_id:
    print(tokenizer.decode(id))
# Out:
# [CLS]
# hello
# world
# [SEP]

# %% [markdown]
# #visualizing tokenization

# %%
# a list of colors in rgb for representing the token
colors = [
    '102;194;165', '252;141;98', '142;160;203',
    '231;138;195', '160;216;84', '255;217;47'
]

# %%
# run function show_token in different colors
def show_tokens(sentence : str , tokenizer_name : str):
  """show the tokens each separated by different color  """

  #load the tokenizer and tokenize input
  tokenizer = AutoTokenizer.from_pretrained(tokenizer_name)
  token_id = tokenizer(sentence).input_ids

  #extract vocabulary lenght
  print(f"Vocabulary lenght : {len(tokenizer.vocab)}")

  #print a colored list of tokens
  for idx , t in enumerate(token_id):
    print(
        f'\x1b[0;30;48;2;{colors[idx % len(colors)]}m' +
            tokenizer.decode(t) +
            '\x1b[0m',
            end=' '
    )

# %%
text = """ enigish is very good language to understand international people talks . $%#
12%23^7v   56 """

# %% [markdown]
# bert-base-cased

# %%
#call the function show the results
show_tokens(text , "bert-base-cased")
# Out:
# Vocabulary lenght : 28996
# [CLS] en ##igi ##sh is very good language to understand international people talks . $ % # 12 % 23 ^ 7 ##v 56 [SEP]

# %%
# know check different model . how the work
show_tokens(text , "bert-base-uncased")
# Out:
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Vocabulary lenght : 30522
# [CLS] en ##ig ##ish is very good language to understand international people talks . $ % # 12 % 23 ^ 7 ##v 56 [SEP]

# %%
show_tokens(text , "bert-large-cased")
# Out:
# config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Vocabulary lenght : 28996
# [CLS] en ##igi ##sh is very good language to understand international people talks . $ % # 12 % 23 ^ 7 ##v 56 [SEP]

# %%
show_tokens(text, "Xenova/gpt-4")
# Out:
# tokenizer_config.json:   0%|          | 0.00/460 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/98.0 [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Vocabulary lenght : 100263
#  en ig ish  is  very  good  language  to  understand  international  people  talks  .  $ % #
#  12 % 23 ^ 7 v      56

# %%
show_tokens(text, "gpt2")
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Vocabulary lenght : 50257
#  en ig ish  is  very  good  language  to  understand  international  people  talks  .  $ % #
#  12 % 23 ^ 7 v      56

# %%
show_tokens(text, "microsoft/Phi-3-mini-4k-instruct")
# Out:
# config.json:   0%|          | 0.00/967 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/306 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/599 [00:00<?, ?B/s]
# Vocabulary lenght : 32011
#  en ig ish is very good language to understand international people tal ks . $ % #
#  1 2 % 2 3 ^ 7 v    5 6
